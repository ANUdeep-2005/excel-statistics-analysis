# %%
import pandas as pd 
import numpy as np
import matplotl as mp

marks = [80,85,84,80,83,84,81,78]
hours = [6,6,6.5,7,8,7,8,5]

print("Mean:",np.mean(marks))
print("Median:",np.median(marks))
print("Varience:",np.var(marks))
print("Standard Deviation:",np.std(marks))
print("corelation:",np.corrcoef(marks,hours))
# Out:
# Mean: 81.875
# Median: 82.0
# Varience: 5.359375
# Standard Deviation: 2.315032397181517
# corelation: [[1.         0.31783036]
#  [0.31783036 1.        ]]
